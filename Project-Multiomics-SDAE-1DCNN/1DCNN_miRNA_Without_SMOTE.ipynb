# %%
import os
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split

from sklearn.svm import SVC
from sklearn.feature_selection import RFE

from imblearn.over_sampling import SMOTE

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score

# %%
# Link notebook with google drive and access data from your personal Gdrive
from google.colab import drive
#Mount Google Drive
drive.mount('/content/gdrive')

#Set the data path for dataset and model location (ex: model_loc = "/content/gdrive/My Drive/Dataset/")
dataset_dir = "/content/gdrive/My Drive/Bio Modelling/data/"
model_loc = "/content/gdrive/My Drive/Bio Modelling/data/"

print(os.listdir(dataset_dir))
# Out:
# Mounted at /content/gdrive
# ['BRCA_label.csv', 'BRCA_miRNA.csv', 'BRCA_DNA_Methylation.csv', 'BRCA_mRNA.csv', 'BRCA_Copy Nunber Variation.csv']

# %%
data = pd.read_csv(dataset_dir+'BRCA_miRNA.csv',index_col=0)
data
# Out:
#               TCGA.3C.AAAU.01  TCGA.3C.AALI.01  TCGA.3C.AALJ.01  \
# hsa.let.7a.1         0.068317        -0.301684        -0.150810
# hsa.let.7a.2         0.068932        -0.318009        -0.122747
# hsa.let.7a.3         0.073899        -0.301310        -0.126333
# hsa.let.7b           0.524562         0.419859        -0.958939
# hsa.let.7c          -1.656853        -0.715963        -0.971038
# ...                       ...              ...              ...
# hsa.mir.95           0.943346        -0.828843        -0.487207
# hsa.mir.96           1.552613         0.599794         1.261482
# hsa.mir.98          -0.143572         1.103662         1.940594
# hsa.mir.99a         -1.251868        -0.627587        -0.848552
# hsa.mir.99b          1.603022        -1.506825         0.787948
#
#               TCGA.3C.AALK.01  TCGA.5L.AAT0.01  TCGA.5T.A9QA.01  \
# hsa.let.7a.1         0.107831         0.395211         1.135212
# hsa.let.7a.2         0.097594         0.412879         1.140183
# hsa.let.7a.3         0.095545         0.418441         1.143605
# hsa.let.7b           0.615389         0.500594         1.159087
# hsa.let.7c           0.711952         0.426323        -1.058870
# ...                       ...              ...              ...
# hsa.mir.95          -0.539524        -0.490655         1.716711
# hsa.mir.96           0.856983         1.188748         0.375870
# hsa.mir.98          -0.831098        -0.885905        -0.922881
# hsa.mir.99a          0.936474         0.449284        -1.316179
# hsa.mir.99b          0.030739        -0.645458         0.931785
#
#               TCGA.A1.A0SB.01  TCGA.A1.A0SE.01  TCGA.A1.A0SF.01  \
# hsa.let.7a.1         1.813887         0.473642        -0.470612
# hsa.let.7a.2         1.790792         0.442224        -0.461217
# hsa.let.7a.3         1.822272         0.431312        -0.470734
# hsa.let.7b           2.113821         0.812876        -0.129307
# hsa.let.7c           2.135373         1.031809         0.864211
# ...                       ...              ...              ...
# hsa.mir.95          -0.311971        -0.207033        -0.411471
# hsa.mir.96           0.297224         0.066368         0.268172
# hsa.mir.98           0.390134        -0.330246        -0.481707
# hsa.mir.99a          2.106744         1.078635         1.255710
# hsa.mir.99b          0.319827         0.089918        -0.443763
#
#               TCGA.A1.A0SG.01  ...  TCGA.UL.AAZ6.01  TCGA.UU.A93S.01  \
# hsa.let.7a.1         0.791968  ...        -3.038971        -0.474111
# hsa.let.7a.2         0.841821  ...        -3.037340        -0.477443
# hsa.let.7a.3         0.805374  ...        -3.017967        -0.474484
# hsa.let.7b           0.867411  ...        -3.509653        -0.855498
# hsa.let.7c           0.071249  ...        -2.454470         0.188937
# ...                       ...  ...              ...              ...
# hsa.mir.95           1.331634  ...        -1.290823        -1.028967
# hsa.mir.96           0.155349  ...         1.077028        -0.538255
# hsa.mir.98           0.490018  ...         1.152087        -0.648284
# hsa.mir.99a         -0.062945  ...        -2.406554         0.465270
# hsa.mir.99b          1.220345  ...         0.695364        -1.324963
#
#               TCGA.V7.A7HQ.01  TCGA.W8.A86G.01  TCGA.WT.AB41.01  \
# hsa.let.7a.1         0.165775         0.706495        -0.086149
# hsa.let.7a.2         0.172506         0.706552        -0.074380
# hsa.let.7a.3         0.164726         0.727433        -0.102883
# hsa.let.7b          -0.359797         0.997679        -0.342075
# hsa.let.7c          -0.001077         1.302563         0.506728
# ...                       ...              ...              ...
# hsa.mir.95           1.079692        -0.906212         0.475039
# hsa.mir.96           0.875546         0.880267         0.479055
# hsa.mir.98           0.562151        -0.826311         0.280432
# hsa.mir.99a          0.281323         1.373466         0.740620
# hsa.mir.99b          1.130022         0.598749        -0.127977
#
#               TCGA.WT.AB44.01  TCGA.XX.A899.01  TCGA.XX.A89A.01  \
# hsa.let.7a.1         0.511958         1.225298         0.667662
# hsa.let.7a.2         0.504240         1.219548         0.666012
# hsa.let.7a.3         0.496009         1.210610         0.675998
# hsa.let.7b           0.422382         0.050804        -0.102655
# hsa.let.7c           1.028977         1.186182         1.534247
# ...                       ...              ...              ...
# hsa.mir.95          -0.867968        -0.019299        -1.125255
# hsa.mir.96           0.988195        -1.079726         0.219581
# hsa.mir.98           0.034551         0.419871         0.277618
# hsa.mir.99a          0.989033         1.595339         1.039647
# hsa.mir.99b         -0.893453        -0.898431        -0.363449
#
#               TCGA.Z7.A8R5.01  TCGA.Z7.A8R6.01
# hsa.let.7a.1        -0.211878         0.474240
# hsa.let.7a.2        -0.210525         0.488117
# hsa.let.7a.3        -0.220135         0.481577
# hsa.let.7b           0.177655        -0.078426
# hsa.let.7c           1.070328        -0.155655
# ...                       ...              ...
# hsa.mir.95          -0.477013         0.266220
# hsa.mir.96           0.480704         0.198107
# hsa.mir.98          -0.187117         0.914841
# hsa.mir.99a          1.008012         0.094512
# hsa.mir.99b         -0.572713         0.859040
#
# [368 rows x 671 columns]

# %%
label = pd.read_csv(dataset_dir+'BRCA_label.csv')
label
# Out:
#     Label
# 0    LumA
# 1    Her2
# 2    LumB
# 3    LumA
# 4    LumA
# ..    ...
# 666  LumA
# 667  LumA
# 668  LumA
# 669  LumA
# 670  LumB
#
# [671 rows x 1 columns]

# %%
#replace label with numerical data
label['Label'].replace('Normal', 0 , inplace=True)
label['Label'].replace('LumA', 1 , inplace=True)
label['Label'].replace('LumB', 2 , inplace=True)
label['Label'].replace('Basal', 3 , inplace=True)
label['Label'].replace('Her2', 4 , inplace=True)

# %%
# Transpose data to match with label
data = data. T
data
# Out:
#                  hsa.let.7a.1  hsa.let.7a.2  hsa.let.7a.3  hsa.let.7b  \
# TCGA.3C.AAAU.01      0.068317      0.068932      0.073899    0.524562
# TCGA.3C.AALI.01     -0.301684     -0.318009     -0.301310    0.419859
# TCGA.3C.AALJ.01     -0.150810     -0.122747     -0.126333   -0.958939
# TCGA.3C.AALK.01      0.107831      0.097594      0.095545    0.615389
# TCGA.5L.AAT0.01      0.395211      0.412879      0.418441    0.500594
# ...                       ...           ...           ...         ...
# TCGA.WT.AB44.01      0.511958      0.504240      0.496009    0.422382
# TCGA.XX.A899.01      1.225298      1.219548      1.210610    0.050804
# TCGA.XX.A89A.01      0.667662      0.666012      0.675998   -0.102655
# TCGA.Z7.A8R5.01     -0.211878     -0.210525     -0.220135    0.177655
# TCGA.Z7.A8R6.01      0.474240      0.488117      0.481577   -0.078426
#
#                  hsa.let.7c  hsa.let.7d  hsa.let.7e  hsa.let.7f.1  \
# TCGA.3C.AAAU.01   -1.656853   -0.038283    0.501125     -2.390084
# TCGA.3C.AALI.01   -0.715963    0.460975   -1.999304     -0.659788
# TCGA.3C.AALJ.01   -0.971038    0.866585    2.074809      1.080746
# TCGA.3C.AALK.01    0.711952   -0.454282    0.227441     -0.735552
# TCGA.5L.AAT0.01    0.426323   -1.545556   -0.952282     -0.280966
# ...                     ...         ...         ...           ...
# TCGA.WT.AB44.01    1.028977   -0.254668    0.528134      0.757211
# TCGA.XX.A899.01    1.186182   -1.238797    0.879213      1.455206
# TCGA.XX.A89A.01    1.534247    0.305716    1.276369      1.253312
# TCGA.Z7.A8R5.01    1.070328   -0.716526   -0.598473     -0.229774
# TCGA.Z7.A8R6.01   -0.155655    1.384395    1.237552      0.851405
#
#                  hsa.let.7f.2  hsa.let.7g  ...  hsa.mir.935  hsa.mir.937  \
# TCGA.3C.AAAU.01     -2.406331   -0.760042  ...     1.795470     0.108421
# TCGA.3C.AALI.01     -0.651943   -1.050266  ...    -0.409131     0.569264
# TCGA.3C.AALJ.01      1.088164    0.523204  ...     0.742000     1.952380
# TCGA.3C.AALK.01     -0.686623   -1.015715  ...    -0.715237     0.119549
# TCGA.5L.AAT0.01     -0.233746   -0.818574  ...    -0.925821    -0.248950
# ...                       ...         ...  ...          ...          ...
# TCGA.WT.AB44.01      0.741367    0.378499  ...    -0.927603    -0.345687
# TCGA.XX.A899.01      1.460326    0.921697  ...     0.232086    -0.066436
# TCGA.XX.A89A.01      1.240593    0.556762  ...    -0.638539    -0.896460
# TCGA.Z7.A8R5.01     -0.190906   -0.465549  ...    -0.356020    -1.035048
# TCGA.Z7.A8R6.01      0.851526    0.409391  ...    -0.789732     1.714101
#
#                  hsa.mir.939  hsa.mir.940  hsa.mir.942  hsa.mir.95  \
# TCGA.3C.AAAU.01     0.179279     1.768897     0.226659    0.943346
# TCGA.3C.AALI.01     0.188875    -0.453994     0.804807   -0.828843
# TCGA.3C.AALJ.01    -1.226285    -0.281690    -0.314543   -0.487207
# TCGA.3C.AALK.01    -0.340371    -0.586990    -0.364370   -0.539524
# TCGA.5L.AAT0.01    -1.439120    -0.707823    -0.109361   -0.490655
# ...                      ...          ...          ...         ...
# TCGA.WT.AB44.01     0.556464    -0.716083    -1.510158   -0.867968
# TCGA.XX.A899.01    -0.521624    -1.400357     0.188031   -0.019299
# TCGA.XX.A89A.01    -0.418889    -0.438539    -1.424222   -1.125255
# TCGA.Z7.A8R5.01     0.003670    -0.570925    -0.979351   -0.477013
# TCGA.Z7.A8R6.01     0.631380     1.543822     1.273811    0.266220
#
#                  hsa.mir.96  hsa.mir.98  hsa.mir.99a  hsa.mir.99b
# TCGA.3C.AAAU.01    1.552613   -0.143572    -1.251868     1.603022
# TCGA.3C.AALI.01    0.599794    1.103662    -0.627587    -1.506825
# TCGA.3C.AALJ.01    1.261482    1.940594    -0.848552     0.787948
# TCGA.3C.AALK.01    0.856983   -0.831098     0.936474     0.030739
# TCGA.5L.AAT0.01    1.188748   -0.885905     0.449284    -0.645458
# ...                     ...         ...          ...          ...
# TCGA.WT.AB44.01    0.988195    0.034551     0.989033    -0.893453
# TCGA.XX.A899.01   -1.079726    0.419871     1.595339    -0.898431
# TCGA.XX.A89A.01    0.219581    0.277618     1.039647    -0.363449
# TCGA.Z7.A8R5.01    0.480704   -0.187117     1.008012    -0.572713
# TCGA.Z7.A8R6.01    0.198107    0.914841     0.094512     0.859040
#
# [671 rows x 368 columns]

# %%
# Ensure the number of rows in data match with label
if data.shape[0] == label.shape[0]:
    # Add the new column to the transposed DataFrame
    data['Label'] = label['Label'].values
else:
    raise ValueError("The number of rows in df2 must match the number of columns in the transposed df1.")

# %%
data
# Out:
#                  hsa.let.7a.1  hsa.let.7a.2  hsa.let.7a.3  hsa.let.7b  \
# TCGA.3C.AAAU.01      0.068317      0.068932      0.073899    0.524562
# TCGA.3C.AALI.01     -0.301684     -0.318009     -0.301310    0.419859
# TCGA.3C.AALJ.01     -0.150810     -0.122747     -0.126333   -0.958939
# TCGA.3C.AALK.01      0.107831      0.097594      0.095545    0.615389
# TCGA.5L.AAT0.01      0.395211      0.412879      0.418441    0.500594
# ...                       ...           ...           ...         ...
# TCGA.WT.AB44.01      0.511958      0.504240      0.496009    0.422382
# TCGA.XX.A899.01      1.225298      1.219548      1.210610    0.050804
# TCGA.XX.A89A.01      0.667662      0.666012      0.675998   -0.102655
# TCGA.Z7.A8R5.01     -0.211878     -0.210525     -0.220135    0.177655
# TCGA.Z7.A8R6.01      0.474240      0.488117      0.481577   -0.078426
#
#                  hsa.let.7c  hsa.let.7d  hsa.let.7e  hsa.let.7f.1  \
# TCGA.3C.AAAU.01   -1.656853   -0.038283    0.501125     -2.390084
# TCGA.3C.AALI.01   -0.715963    0.460975   -1.999304     -0.659788
# TCGA.3C.AALJ.01   -0.971038    0.866585    2.074809      1.080746
# TCGA.3C.AALK.01    0.711952   -0.454282    0.227441     -0.735552
# TCGA.5L.AAT0.01    0.426323   -1.545556   -0.952282     -0.280966
# ...                     ...         ...         ...           ...
# TCGA.WT.AB44.01    1.028977   -0.254668    0.528134      0.757211
# TCGA.XX.A899.01    1.186182   -1.238797    0.879213      1.455206
# TCGA.XX.A89A.01    1.534247    0.305716    1.276369      1.253312
# TCGA.Z7.A8R5.01    1.070328   -0.716526   -0.598473     -0.229774
# TCGA.Z7.A8R6.01   -0.155655    1.384395    1.237552      0.851405
#
#                  hsa.let.7f.2  hsa.let.7g  ...  hsa.mir.937  hsa.mir.939  \
# TCGA.3C.AAAU.01     -2.406331   -0.760042  ...     0.108421     0.179279
# TCGA.3C.AALI.01     -0.651943   -1.050266  ...     0.569264     0.188875
# TCGA.3C.AALJ.01      1.088164    0.523204  ...     1.952380    -1.226285
# TCGA.3C.AALK.01     -0.686623   -1.015715  ...     0.119549    -0.340371
# TCGA.5L.AAT0.01     -0.233746   -0.818574  ...    -0.248950    -1.439120
# ...                       ...         ...  ...          ...          ...
# TCGA.WT.AB44.01      0.741367    0.378499  ...    -0.345687     0.556464
# TCGA.XX.A899.01      1.460326    0.921697  ...    -0.066436    -0.521624
# TCGA.XX.A89A.01      1.240593    0.556762  ...    -0.896460    -0.418889
# TCGA.Z7.A8R5.01     -0.190906   -0.465549  ...    -1.035048     0.003670
# TCGA.Z7.A8R6.01      0.851526    0.409391  ...     1.714101     0.631380
#
#                  hsa.mir.940  hsa.mir.942  hsa.mir.95  hsa.mir.96  hsa.mir.98  \
# TCGA.3C.AAAU.01     1.768897     0.226659    0.943346    1.552613   -0.143572
# TCGA.3C.AALI.01    -0.453994     0.804807   -0.828843    0.599794    1.103662
# TCGA.3C.AALJ.01    -0.281690    -0.314543   -0.487207    1.261482    1.940594
# TCGA.3C.AALK.01    -0.586990    -0.364370   -0.539524    0.856983   -0.831098
# TCGA.5L.AAT0.01    -0.707823    -0.109361   -0.490655    1.188748   -0.885905
# ...                      ...          ...         ...         ...         ...
# TCGA.WT.AB44.01    -0.716083    -1.510158   -0.867968    0.988195    0.034551
# TCGA.XX.A899.01    -1.400357     0.188031   -0.019299   -1.079726    0.419871
# TCGA.XX.A89A.01    -0.438539    -1.424222   -1.125255    0.219581    0.277618
# TCGA.Z7.A8R5.01    -0.570925    -0.979351   -0.477013    0.480704   -0.187117
# TCGA.Z7.A8R6.01     1.543822     1.273811    0.266220    0.198107    0.914841
#
#                  hsa.mir.99a  hsa.mir.99b  Label
# TCGA.3C.AAAU.01    -1.251868     1.603022      1
# TCGA.3C.AALI.01    -0.627587    -1.506825      4
# TCGA.3C.AALJ.01    -0.848552     0.787948      2
# TCGA.3C.AALK.01     0.936474     0.030739      1
# TCGA.5L.AAT0.01     0.449284    -0.645458      1
# ...                      ...          ...    ...
# TCGA.WT.AB44.01     0.989033    -0.893453      1
# TCGA.XX.A899.01     1.595339    -0.898431      1
# TCGA.XX.A89A.01     1.039647    -0.363449      1
# TCGA.Z7.A8R5.01     1.008012    -0.572713      1
# TCGA.Z7.A8R6.01     0.094512     0.859040      2
#
# [671 rows x 369 columns]

# %%
# print the total number of data with missing values across all columns
print(data.isna().sum().sum())
# Out:
# 0

# %%
# print the total number of data with duplicated values across all columns
print(data.duplicated().sum())
# Out:
# 0

# %%
print(data["Label"].value_counts()[0])
print(data["Label"].value_counts()[1])
print(data["Label"].value_counts()[2])
print(data["Label"].value_counts()[3])
print(data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %%
# Separate features and target
y = data['Label'].values
x = data.drop(['Label'],axis=1)

# %%
# Normalization
scaler = MinMaxScaler(feature_range=(-1, 1))
X_normalized = scaler.fit_transform(x)

# Apply the scaler to the DataFrame
x = pd.DataFrame(scaler.fit_transform(X_normalized), index = x.index, columns = x.columns)
x
# Out:
#                  hsa.let.7a.1  hsa.let.7a.2  hsa.let.7a.3  hsa.let.7b  \
# TCGA.3C.AAAU.01      0.077127      0.074798      0.076423    0.285187
# TCGA.3C.AALI.01     -0.025803     -0.033109     -0.028039    0.251832
# TCGA.3C.AALJ.01      0.016169      0.021344      0.020677   -0.187414
# TCGA.3C.AALK.01      0.088120      0.082791      0.082449    0.314122
# TCGA.5L.AAT0.01      0.168065      0.170715      0.172346    0.277552
# ...                       ...           ...           ...         ...
# TCGA.WT.AB44.01      0.200543      0.196193      0.193941    0.252636
# TCGA.XX.A899.01      0.398986      0.395673      0.392892    0.134261
# TCGA.XX.A89A.01      0.243858      0.241307      0.244052    0.085374
# TCGA.Z7.A8R5.01     -0.000820     -0.003135     -0.005439    0.174672
# TCGA.Z7.A8R6.01      0.190050      0.191697      0.189924    0.093092
#
#                  hsa.let.7c  hsa.let.7d  hsa.let.7e  hsa.let.7f.1  \
# TCGA.3C.AAAU.01   -0.530754   -0.014734    0.392527     -0.530835
# TCGA.3C.AALI.01   -0.232318    0.133965   -0.391993     -0.070587
# TCGA.3C.AALJ.01   -0.313224    0.254772    0.886277      0.392385
# TCGA.3C.AALK.01    0.220596   -0.138636    0.306657     -0.090740
# TCGA.5L.AAT0.01    0.129999   -0.463662   -0.063486      0.030178
# ...                     ...         ...         ...           ...
# TCGA.WT.AB44.01    0.321152   -0.079183    0.401001      0.306327
# TCGA.XX.A899.01    0.371015   -0.372297    0.511154      0.491990
# TCGA.XX.A89A.01    0.481416    0.087723    0.635763      0.438287
# TCGA.Z7.A8R5.01    0.334268   -0.216743    0.047523      0.043795
# TCGA.Z7.A8R6.01   -0.054596    0.408997    0.623584      0.331382
#
#                  hsa.let.7f.2  hsa.let.7g  ...  hsa.mir.935  hsa.mir.937  \
# TCGA.3C.AAAU.01     -0.523447   -0.203173  ...     0.205520    -0.387108
# TCGA.3C.AALI.01     -0.059396   -0.287028  ...    -0.623367    -0.216862
# TCGA.3C.AALJ.01      0.400877    0.167600  ...    -0.190564     0.294092
# TCGA.3C.AALK.01     -0.068569   -0.277045  ...    -0.738457    -0.382997
# TCGA.5L.AAT0.01      0.051221   -0.220085  ...    -0.817632    -0.519129
# ...                       ...         ...  ...          ...          ...
# TCGA.WT.AB44.01      0.309146    0.125790  ...    -0.818302    -0.554866
# TCGA.XX.A899.01      0.499317    0.282738  ...    -0.382282    -0.451704
# TCGA.XX.A89A.01      0.441196    0.177296  ...    -0.709620    -0.758334
# TCGA.Z7.A8R5.01      0.062552   -0.118084  ...    -0.603398    -0.809531
# TCGA.Z7.A8R6.01      0.338284    0.134715  ...    -0.766465     0.206066
#
#                  hsa.mir.939  hsa.mir.940  hsa.mir.942  hsa.mir.95  \
# TCGA.3C.AAAU.01    -0.236899     0.523473    -0.247222    0.175782
# TCGA.3C.AALI.01    -0.233333    -0.324011    -0.069232   -0.441474
# TCGA.3C.AALJ.01    -0.759165    -0.258319    -0.413837   -0.322482
# TCGA.3C.AALK.01    -0.429986    -0.374716    -0.429177   -0.340704
# TCGA.5L.AAT0.01    -0.838248    -0.420784    -0.350669   -0.323682
# ...                      ...          ...          ...         ...
# TCGA.WT.AB44.01    -0.096748    -0.423933    -0.781921   -0.455101
# TCGA.XX.A899.01    -0.497334    -0.684815    -0.259114   -0.159509
# TCGA.XX.A89A.01    -0.459161    -0.318118    -0.755465   -0.544714
# TCGA.Z7.A8R5.01    -0.302150    -0.368591    -0.618506   -0.318931
# TCGA.Z7.A8R6.01    -0.068912     0.437663     0.075156   -0.060062
#
#                  hsa.mir.96  hsa.mir.98  hsa.mir.99a  hsa.mir.99b
# TCGA.3C.AAAU.01    0.629658    0.128714    -0.284763     0.563647
# TCGA.3C.AALI.01    0.322503    0.453843    -0.089802    -0.456717
# TCGA.3C.AALJ.01    0.535808    0.672014    -0.158809     0.296215
# TCGA.3C.AALK.01    0.405412   -0.050510     0.398651     0.047769
# TCGA.5L.AAT0.01    0.512361   -0.064797     0.246503    -0.174096
# ...                     ...         ...          ...          ...
# TCGA.WT.AB44.01    0.447710    0.175147     0.415065    -0.255465
# TCGA.XX.A899.01   -0.218913    0.275592     0.604414    -0.257099
# TCGA.XX.A89A.01    0.199936    0.238510     0.430872    -0.081567
# TCGA.Z7.A8R5.01    0.284113    0.117363     0.420993    -0.150228
# TCGA.Z7.A8R6.01    0.193014    0.404621     0.135708     0.319541
#
# [671 rows x 368 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=300)

# Fit RFE on the training data
rfe.fit(X_train, y_train)

# Transform the training and test sets to include only the selected features
x_train_rfe = rfe.transform(X_train)
x_test_rfe = rfe.transform(X_test)

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features = X_train.columns[rfe.support_]

X_train_rfe = pd.DataFrame(x_train_rfe, columns=selected_features, index=X_train.index)
X_test_rfe = pd.DataFrame(x_test_rfe, columns=selected_features, index=X_test.index)

# %%
# Define the model
model = Sequential()

# Add convolutional layer
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(300, 1)))
model.add(MaxPooling1D(pool_size=2))

# Add more convolutional layers
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

# Add another convolutional layer
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))

# Flatten the output
model.add(Flatten())

# Add dense layers
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(5, activation='softmax'))  # 5 classes

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 298, 32)           128
#
#  max_pooling1d (MaxPooling1  (None, 149, 32)           0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 147, 64)           6208
#
#  max_pooling1d_1 (MaxPoolin  (None, 73, 64)            0
#  g1D)
#
#  conv1d_2 (Conv1D)           (None, 71, 128)           24704
#
#  max_pooling1d_2 (MaxPoolin  (None, 35, 128)           0
#  g1D)
#
#  flatten (Flatten)           (None, 4480)              0
#
#  dense (Dense)               (None, 128)               573568
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 605253 (2.31 MB)
# Trainable params: 605253 (2.31 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# Train the model with early stopping
model.fit(X_train_rfe, y_train, epochs=250, batch_size=32, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/250
# 12/12 [==============================] - 6s 66ms/step - loss: 1.3148 - accuracy: 0.4880 - val_loss: 1.2599 - val_accuracy: 0.5213
# Epoch 2/250
# 12/12 [==============================] - 0s 8ms/step - loss: 1.0713 - accuracy: 0.6160 - val_loss: 1.1637 - val_accuracy: 0.6170
# Epoch 3/250
# 12/12 [==============================] - 0s 8ms/step - loss: 0.9500 - accuracy: 0.6613 - val_loss: 1.0834 - val_accuracy: 0.6702
# Epoch 4/250
# 12/12 [==============================] - 0s 10ms/step - loss: 0.8960 - accuracy: 0.6880 - val_loss: 0.9924 - val_accuracy: 0.6383
# Epoch 5/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7657 - accuracy: 0.7173 - val_loss: 0.8921 - val_accuracy: 0.7234
# Epoch 6/250
# 12/12 [==============================] - 0s 9ms/step - loss: 0.7045 - accuracy: 0.7467 - val_loss: 0.7772 - val_accuracy: 0.7128
# Epoch 7/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5927 - accuracy: 0.7787 - val_loss: 0.6971 - val_accuracy: 0.7766
# Epoch 8/250
# 12/12 [==============================] - 0s 8ms/step - loss: 0.5244 - accuracy: 0.8213 - val_loss: 0.7147 - val_accuracy: 0.7766
# Epoch 9/250
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4364 - accuracy: 0.8400 - val_loss: 0.7253 - val_accuracy: 0.8191
# Epoch 10/250
# 12/12 [==============================] - 0s 8ms/step - loss: 0.4141 - accuracy: 0.8640 - val_loss: 0.7561 - val_accuracy: 0.7979
# Epoch 11/250
# 12/12 [==============================] - 0s 10ms/step - loss: 0.3984 - accuracy: 0.8560 - val_loss: 0.6209 - val_accuracy: 0.7979
# Epoch 12/250
# 12/12 [==============================] - 0s 8ms/step - loss: 0.3022 - accuracy: 0.9093 - val_loss: 0.6937 - val_accuracy: 0.8617
# Epoch 13/250
# 12/12 [==============================] - 0s 9ms/step - loss: 0.2805 - accuracy: 0.8880 - val_loss: 0.6849 - val_accuracy: 0.8191
# Epoch 14/250
# 12/12 [==============================] - 0s 10ms/step - loss: 0.2233 - accuracy: 0.9307 - val_loss: 0.6935 - val_accuracy: 0.8404
# Epoch 15/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1888 - accuracy: 0.9413 - val_loss: 0.7090 - val_accuracy: 0.8085
# Epoch 16/250
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1971 - accuracy: 0.9253 - val_loss: 0.8299 - val_accuracy: 0.7553
# Epoch 17/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1436 - accuracy: 0.9520 - val_loss: 0.7582 - val_accuracy: 0.8404
# Epoch 18/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1088 - accuracy: 0.9760 - val_loss: 0.8718 - val_accuracy: 0.8404
# Epoch 19/250
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1172 - accuracy: 0.9627 - val_loss: 0.8711 - val_accuracy: 0.7979
# Epoch 20/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1048 - accuracy: 0.9680 - val_loss: 0.9973 - val_accuracy: 0.7979
# Epoch 21/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0916 - accuracy: 0.9653 - val_loss: 0.8445 - val_accuracy: 0.8085
# Epoch 22/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0802 - accuracy: 0.9813 - val_loss: 1.1450 - val_accuracy: 0.8085
# Epoch 23/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0668 - accuracy: 0.9840 - val_loss: 0.9762 - val_accuracy: 0.7872
# Epoch 24/250
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0667 - accuracy: 0.9867 - val_loss: 1.0895 - val_accuracy: 0.7660
# Epoch 25/250
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0487 - accuracy: 0.9840 - val_loss: 1.0451 - val_accuracy: 0.7979
# Epoch 26/250
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0593 - accuracy: 0.9787 - val_loss: 1.0159 - val_accuracy: 0.8085
# Epoch 27/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0612 - accuracy: 0.9813 - val_loss: 1.0447 - val_accuracy: 0.7979
# Epoch 28/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0504 - accuracy: 0.9893 - val_loss: 0.9662 - val_accuracy: 0.8191
# Epoch 29/250
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0301 - accuracy: 0.9973 - val_loss: 1.0573 - val_accuracy: 0.7979
# Epoch 30/250
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0273 - accuracy: 0.9973 - val_loss: 1.0816 - val_accuracy: 0.8191
# Epoch 31/250
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0195 - accuracy: 0.9973 - val_loss: 1.1636 - val_accuracy: 0.7979

# %%
# Predict probabilities
y_pred_prob = model.predict(X_test_rfe)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# 7/7 [==============================] - 0s 29ms/step
# Accuracy: 0.7673267326732673
